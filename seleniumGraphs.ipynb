# %%
import pandas as pd

# %%
fortune17 = pd.read_csv('fortune2017.csv')

# %%
fortune18 = pd.read_csv('fortune2018.csv')

# %%
fortune19 = pd.read_csv('fortune2019.csv')

# %%
fortune = pd.read_csv('fortune.csv')

# %%
fortune19
# Out:
#      rank                     company      revenues revenue % change  \
# 0       1                     Walmart  $514,405.00             2.80%
# 1       2                 Exxon Mobil  $290,212.00            18.80%
# 2       3                       Apple  $265,595.00            15.90%
# 3       4          Berkshire Hathaway  $247,837.00             2.40%
# 4       5                  Amazon.com  $232,887.00            30.90%
# 5       6          UnitedHealth Group  $226,247.00            12.50%
# 6       7                    McKesson  $208,357.00             4.90%
# 7       8                  CVS Health  $194,579.00             5.30%
# 8       9                        AT&T  $170,756.00             6.40%
# 9      10           AmerisourceBergen  $167,939.60             9.70%
# 10     11                     Chevron  $166,339.00            23.60%
# 11     12                  Ford Motor  $160,338.00             2.30%
# 12     13              General Motors  $147,049.00            -6.50%
# ...

# %%
##stats.describe(sepal_len)
### for final part

##plt.hist(df['imdb_score'])             for means of each year
# %matplotlib inline

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
plt.style.use('ggplot')
import seaborn as sns

# %%
# plt.figure(figsize=(12,6))
# plt.scatter(fortune17['revenue % change'], fortune17['profits % change'])
# plt.xlabel('Revenue % Change')
# plt.ylabel('Profit % Change')

# %%
import plotly
# connected=True means it will download the latest version of plotly javascript library.
plotly.offline.init_notebook_mode(connected=True)
from plotly.graph_objs import Figure, Histogram, Layout
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
from plotly.graph_objs import Scatter


data = [Scatter(x=fortune17['revenue % change'], y=fortune17['profits % change'], mode = 'markers', text=fortune17['company'])]
layout = Layout(title="Revenue % Change vs Profit % Change")

fig = Figure(data=data, layout=layout)

plotly.offline.iplot(fig, show_link=False)
# Out:
# <div id="368bf729-5aa9-452d-8da8-851b7eccfa86" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("368bf729-5aa9-452d-8da8-851b7eccfa86", [{"type": "scatter", "x": ["0.008", "0.061", "-0.077", "-0.167", "0.062", "0.177", "0.158", "0.092", "0.116", "0.015", "0.08", "0.271", "-0.098", "-0.043", "0.185", "0.022", "0.134", "0.05", "-0.18", "-0.029", "0.044", "-0.014", "0.069", "-0.016", "0.046", "0.007", "0.204", "-0.088", "0.072", "-0.067", "0.079", "-0.031", "0.006", "-0.169", "0.026", "-0.089", "-0.142", "-0.058", "0.034", "0.101", "0.181", "-0.093", "0.047", "-0.004", "-0.079", "0.044", "0.073", "0.029", "1.159", "-0.062", "-0.135", "0.06", "0.002", "0.081", "-0.102", "0.098", "0.035", "0.061", "-", "0.002", "-0.533", "-0.013", "0.027", "-0.055", "-0.111", "0.786", "-0.02", "-0.004", "0.008", "0.047", 
# ...

# %%
from plotly.graph_objs import Scatter


data = [Scatter(x=fortune17['revenues'], y=fortune17['market val'], mode = 'markers', text=fortune17['company'])]
layout = Layout(title="Revenue vs Market Val")

fig = Figure(data=data, layout=layout)

plotly.offline.iplot(fig, show_link=False)
# Out:
# <div id="b6cb0c5e-4fa6-4090-b7a2-3094d70af4b0" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("b6cb0c5e-4fa6-4090-b7a2-3094d70af4b0", [{"type": "scatter", "x": [485873.0, 223604.0, 215639.0, 205004.0, 192487.0, 184840.0, 177526.0, 166380.0, 163786.0, 151800.0, 146850.0, 135987.0, 126661.0, 125980.0, 121546.0, 118719.0, 117351.0, 115337.0, 107567.0, 107162.0, 105486.0, 100288.0, 94595.0, 94571.0, 94176.0, 93662.0, 90272.0, 85320.0, 84863.0, 82386.0, 80403.0, 79919.0, 76132.0, 72396.0, 71890.0, 71726.0, 70166.0, 69495.0, 65665.0, 65017.0, 64806.0, 63476.0, 63155.0, 62799.0, 62346.0, 60906.0, 59387.0, 58779.0, 58734.0, 57244.0, 55858.0, 55632.0, 54379.0, 52824.0, 52367.0, 50658.0, 50367.0, 50365.0, 50123.0, 49247.0, 48238.0, 48158.0, 44747.0, 41863.0, 40787.0, 40721.0, 40180.0, 40074.0, 39807.0, 39668
# ...

# %%
fortune
# Out:
#       rank                                 company  revenues revenue % change  \
# 0        1                             Walmart2019  514405.0            0.028
# 1        2                         Exxon Mobil2019  290212.0            0.188
# 2        3                               Apple2019  265595.0            0.159
# 3        4                  Berkshire Hathaway2019  247837.0            0.024
# 4        5                          Amazon.com2019  232887.0            0.309
# 5        6                  UnitedHealth Group2019  226247.0            0.125
# 6        7                            McKesson2019  208357.0            0.049
# 7        8                          CVS Health2019  194579.0            0.053
# 8        9                                AT&T2019  170756.0            0.064
# 9       10                   AmerisourceBergen2019  167939.6            0.097
# 10      11                             Chevron2019  166339.0            0.236
# ...

# %%
from plotly.graph_objs import Scatter
import pandas as pd

fortune= pd.read_csv("fortune.csv")

data = [Scatter(x=fortune['revenues'], y=fortune['market val'], mode = 'markers', text=fortune['company'])]
layout = Layout(title="Revenue vs Market Val")

fig = Figure(data=data, layout=layout)

plotly.offline.iplot(fig, show_link=False)

# fig = go.Figure(fortune=go.Scatter(x=fortune['revenues'],
#                                 y=fortune['market val'],
#                                 mode='markers',
#                                 marker_color=fortune['year'],
#                                 text=fortune['company'])) # hover text goes here

# fig.update_layout(title='Revenues Vs Market Val')
# fig.show()
# Out:
# <div id="1a8b8875-5f6b-4828-a938-9a55fd5dce40" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("1a8b8875-5f6b-4828-a938-9a55fd5dce40", [{"type": "scatter", "x": [514405.0, 290212.0, 265595.0, 247837.0, 232887.0, 226247.0, 208357.0, 194579.0, 170756.0, 167939.6, 166339.0, 160338.0, 147049.0, 141576.0, 136819.0, 136809.0, 131537.0, 131412.0, 130863.0, 121162.0, 120268.0, 120101.0, 114217.0, 111407.0, 110584.0, 110360.0, 108203.0, 101127.0, 101060.0, 97120.0, 97102.0, 94507.0, 92105.0, 90621.0, 85977.0, 81732.2, 81581.0, 79591.0, 75356.0, 73598.0, 71861.0, 71309.0, 70848.0, 67941.0, 66832.0, 66501.0, 65450.0, 64661.0, 64341.0, 62992.0, 60116.0, 59924.6, 59434.0, 58727.3, 58472.0, 56912.0, 55838.0, 54722.0, 54436.0, 53762.0, 53647.0, 52528.0, 50193.0, 49330.0, 48650.0, 47389.0, 46677.0, 44541.0, 44438.0
# ...

# %%
from plotly.graph_objs import Scatter


data = [Scatter(x=fortune['revenue % change'], y=fortune['profits % change'], mode = 'markers', text=fortune['company'])]
layout = Layout(title="Revenue % Change vs Profit % Change")

fig = Figure(data=data, layout=layout)

plotly.offline.iplot(fig, show_link=False)
# Out:
# <div id="296211cc-1338-420a-9526-a7eb0c878e3e" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("296211cc-1338-420a-9526-a7eb0c878e3e", [{"type": "scatter", "x": ["0.028", "0.188", "0.159", "0.024", "0.309", "0.125", "0.049", "0.053", "0.064", "0.097", "0.236", "0.023", "-0.065", "0.097", "0.234", "0.053", "0.113", "0.154", "0.038", "-0.012", "-0.016", "0.069", "0.247", "0.26", "0.103", "0.227", "0.072", "0.083", "0.034", "0.104", "0.436", "0.118", "0.023", "0.152", "0.372", "0.043", "0.067", "0.006", "0.048", "-0.014", "0.091", "0.039", "0.129", "0.027", "0.009", "0.111", "0.085", "0.018", "0.058", "0.055", "0.238", "0.004", "0.078", "0.061", "0.123", "0.058", "0.374", "0.204", "0.146", "0.053", "0.021", "0.243", "0.15", "0.028", "0.169", "-0.043", "-0.02", "0.055", "0.077", "0.049", "0.027", "0.216
# ...

# %%
from plotly.graph_objs import Scatter


data = [Scatter(x=fortune['revenues'], y=fortune['profits'], mode = 'markers', text=fortune['company'])]
layout = Layout(title="Revenue vs Profit")

fig = Figure(data=data, layout=layout)

plotly.offline.iplot(fig, show_link=False)
# Out:
# <div id="ddc65578-846d-4121-87b4-a0ee79c3f0c4" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("ddc65578-846d-4121-87b4-a0ee79c3f0c4", [{"type": "scatter", "x": [514405.0, 290212.0, 265595.0, 247837.0, 232887.0, 226247.0, 208357.0, 194579.0, 170756.0, 167939.6, 166339.0, 160338.0, 147049.0, 141576.0, 136819.0, 136809.0, 131537.0, 131412.0, 130863.0, 121162.0, 120268.0, 120101.0, 114217.0, 111407.0, 110584.0, 110360.0, 108203.0, 101127.0, 101060.0, 97120.0, 97102.0, 94507.0, 92105.0, 90621.0, 85977.0, 81732.2, 81581.0, 79591.0, 75356.0, 73598.0, 71861.0, 71309.0, 70848.0, 67941.0, 66832.0, 66501.0, 65450.0, 64661.0, 64341.0, 62992.0, 60116.0, 59924.6, 59434.0, 58727.3, 58472.0, 56912.0, 55838.0, 54722.0, 54436.0, 53762.0, 53647.0, 52528.0, 50193.0, 49330.0, 48650.0, 47389.0, 46677.0, 44541.0, 44438.0
# ...

# %%
from plotly.graph_objs import Scatter


data = [Scatter(x=fortune['revenue % change'], y=fortune['profits'], mode = 'markers', text=fortune['company'])]
layout = Layout(title="Revenue % Change vs Profit")

fig = Figure(data=data, layout=layout)

plotly.offline.iplot(fig, show_link=False)
# Out:
# <div id="8a213bd7-2ec0-4b74-ae9f-f4123e99e84b" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("8a213bd7-2ec0-4b74-ae9f-f4123e99e84b", [{"type": "scatter", "x": ["0.028", "0.188", "0.159", "0.024", "0.309", "0.125", "0.049", "0.053", "0.064", "0.097", "0.236", "0.023", "-0.065", "0.097", "0.234", "0.053", "0.113", "0.154", "0.038", "-0.012", "-0.016", "0.069", "0.247", "0.26", "0.103", "0.227", "0.072", "0.083", "0.034", "0.104", "0.436", "0.118", "0.023", "0.152", "0.372", "0.043", "0.067", "0.006", "0.048", "-0.014", "0.091", "0.039", "0.129", "0.027", "0.009", "0.111", "0.085", "0.018", "0.058", "0.055", "0.238", "0.004", "0.078", "0.061", "0.123", "0.058", "0.374", "0.204", "0.146", "0.053", "0.021", "0.243", "0.15", "0.028", "0.169", "-0.043", "-0.02", "0.055", "0.077", "0.049", "0.027", "0.216
# ...

# %%
from plotly.graph_objs import Scatter
import pandas as pd

fortune= pd.read_csv("fortune.csv")

data = [Scatter(x=fortune['assets'], y=fortune['market val'], mode = 'markers', text=fortune['company'])]
layout = Layout(title="Assets vs Market Val")

fig = Figure(data=data, layout=layout)

plotly.offline.iplot(fig, show_link=False)
# Out:
# <div id="1a9712a3-0dda-4d80-be8b-47283dc33da2" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("1a9712a3-0dda-4d80-be8b-47283dc33da2", [{"type": "scatter", "x": ["$219,295.00 ", "$346,196.00 ", "$365,725.00 ", "$707,794.00 ", "$162,648.00 ", "$152,221.00 ", "$60,381.00 ", "$196,456.00 ", "$531,864.00 ", "$37,669.80 ", "$253,863.00 ", "$256,540.00 ", "$227,339.00 ", "$40,830.00 ", "$232,792.00 ", "$39,951.00 ", "$68,124.00 ", "$2,622,532.00 ", "$264,829.00 ", "$38,118.00 ", "$309,129.00 ", "$3,418,318.00 ", "$54,302.00 ", "$50,155.00 ", "$2,354,507.00 ", "$258,848.00 ", "$44,003.00 ", "$117,359.00 ", "$1,895,883.00 ", "$1,917,383.00 ", "$92,940.00 ", "$251,684.00 ", "$71,571.00 ", "$111,820.00 ", "$188,030.00 ", "$272,518.40 ", "$152,954.00 ", "$123,382.00 ", "$41,290.00 ", "$2,063,060.00 ", "$50,016
# ...

# %%
from plotly.graph_objs import Scatter
import pandas as pd

fortune= pd.read_csv("fortune.csv")

data = [Scatter(x=fortune['employees'], y=fortune['revenues'], mode = 'markers', text=fortune['company'])]
layout = Layout(title="Employees vs Revenues")

fig = Figure(data=data, layout=layout)

plotly.offline.iplot(fig, show_link=False)
# Out:
# <div id="51aedf4b-28a8-44be-8d0b-9e2f0e2d07ca" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("51aedf4b-28a8-44be-8d0b-9e2f0e2d07ca", [{"type": "scatter", "x": ["2,200,000", "71,000", "132,000", "389,000", "647,500", "300,000", "68,000", "295,000", "268,220", "20,500", "48,600", "199,000", "173,000", "194,000", "98,771", "50,200", "299,000", "256,105", "144,500", "453,000", "283,000", "7,400", "14,200", "10,261", "204,489", "131,000", "413,000", "153,000", "258,700", "204,000", "60,350", "184,000", "63,900", "157,000", "98,000", "56,788", "135,100", "381,100", "360,000", "6,621", "364,575", "245,000", "107,400", "48,000", "92,000", "240,200", "359,000", "267,000", "31,600", "50,492", "47,300", "275,000", "201,000", "67,000", "55,000", "41,600", "35,587", "104,000", "11,768", "105,000", "92,400", "3
# ...

# %%
from plotly.graph_objs import Scatter
import pandas as pd

fortune= pd.read_csv("fortune.csv")

data = [Scatter(x=fortune['employees'], y=fortune['market val'], mode = 'markers', text=fortune['company'])]
layout = Layout(title="Employees vs Market Value")

fig = Figure(data=data, layout=layout)

plotly.offline.iplot(fig, show_link=False)
# Out:
# <div id="11607b91-9429-4efc-95cc-d4b7756ed00d" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("11607b91-9429-4efc-95cc-d4b7756ed00d", [{"type": "scatter", "x": ["2,200,000", "71,000", "132,000", "389,000", "647,500", "300,000", "68,000", "295,000", "268,220", "20,500", "48,600", "199,000", "173,000", "194,000", "98,771", "50,200", "299,000", "256,105", "144,500", "453,000", "283,000", "7,400", "14,200", "10,261", "204,489", "131,000", "413,000", "153,000", "258,700", "204,000", "60,350", "184,000", "63,900", "157,000", "98,000", "56,788", "135,100", "381,100", "360,000", "6,621", "364,575", "245,000", "107,400", "48,000", "92,000", "240,200", "359,000", "267,000", "31,600", "50,492", "47,300", "275,000", "201,000", "67,000", "55,000", "41,600", "35,587", "104,000", "11,768", "105,000", "92,400", "3
# ...

# %%
from plotly.graph_objs import Scatter
import pandas as pd

fortune= pd.read_csv("fortune.csv")

data = [Scatter(x=fortune['employees'], y=fortune['profits'], mode = 'markers', text=fortune['company'])]
layout = Layout(title="Employees vs Profits")

fig = Figure(data=data, layout=layout)

plotly.offline.iplot(fig, show_link=False)
# Out:
# <div id="15fc8c3f-64e3-4bbe-bf18-898515feeb16" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("15fc8c3f-64e3-4bbe-bf18-898515feeb16", [{"type": "scatter", "x": ["2,200,000", "71,000", "132,000", "389,000", "647,500", "300,000", "68,000", "295,000", "268,220", "20,500", "48,600", "199,000", "173,000", "194,000", "98,771", "50,200", "299,000", "256,105", "144,500", "453,000", "283,000", "7,400", "14,200", "10,261", "204,489", "131,000", "413,000", "153,000", "258,700", "204,000", "60,350", "184,000", "63,900", "157,000", "98,000", "56,788", "135,100", "381,100", "360,000", "6,621", "364,575", "245,000", "107,400", "48,000", "92,000", "240,200", "359,000", "267,000", "31,600", "50,492", "47,300", "275,000", "201,000", "67,000", "55,000", "41,600", "35,587", "104,000", "11,768", "105,000", "92,400", "3
# ...

# %%
plt.figure(figsize=(12,6))
fortune.groupby('year')['revenues'].mean().plot.bar(color='b')

# %%
plt.figure(figsize=(12,6))
fortune.groupby('year')['assets'].mean().plot.bar(color='b')
